# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data=pd.read_csv("/content/drive/My Drive/Colab Notebooks/Seboarn/tips.csv")

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#correlation with Heatmap

# %%
data_corr=data.corr()

# %%
data_corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
data.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
#numerical features

# %%
sns.heatmap(data_corr,annot=True)

# %%
sns.scatterplot(x="total_bill", y="tip",data=data,)

# %%
sns.distplot(data["total_bill"]) #histogram #kde on y axis displa in percentage

# %%
sns.distplot(data["total_bill"],kde=False) #histogram #kde off display actual value

# %%
sns.distplot(data.tip) #univariate #histogram

# %%
#join plot do univariate analysis , bivariate

# %%
sns.jointplot(x="tip",y="total_bill",data=data,kind="hex",)

# %%
sns.jointplot(x="total_bill",y="tip",data=data,kind="reg")

# %%
#more than two features and they are independant, integer or ploting value

# %%
sns.pairplot(data)

# %%
sns.pairplot(data=data, hue="sex")

# %%
sns.pairplot(data=data, hue="smoker")

# %%
#categorical fetures

# %%
sns.countplot(x="sex", data=data,)

# %%
data["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
sns.countplot(x="smoker",data=data) # smoker yes no

# %%
sns.countplot(x="smoker",hue="sex",data=data)

# %%
data["smoker"].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.countplot(x="day",data=data)

# %%
data["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
sns.countplot(y="day",data=data,)

# %%
sns.countplot(y="sex", data=data)

# %%
#bar plot same as count plot but value give both x and y axis value one of them is numeric

# %%
sns.barplot(x="total_bill",y="sex", data=data) #univariate #sex

# %%
sns.barplot(x="total_bill",y="smoker", data=data) #univariate

# %%
sns.barplot(y="total_bill",x="smoker", data=data) #univariate #smoker

# %%
#box plot #whisker plot also

# %%
sns.boxplot(x="sex",y="total_bill",data=data)

# %%
sns.boxplot(x="smoker",y="total_bill",data=data) #percentile

# %%
sns.boxplot(x="day",y="total_bill",data=data)

# %%
sns.boxplot(x="day",y="total_bill",data=data,palette="rainbow")

# %%
sns.boxplot(data=data, orient="v")

# %%
sns.boxplot(x="total_bill",y="day",hue="smoker",data=data)

# %%
#violin plot

# %%
#distribution of data with respect to Kernal density estimation with box plot

# %%
sns.violinplot(x="total_bill",y="day",data=data)

# %%
sns.violinplot(x="total_bill",y="day",hue="smoker",data=data) # hue on smoker on day
